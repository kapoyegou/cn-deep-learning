# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = [[source_vocab_to_int.get(word, source_vocab_to_int['<UNK>']) for word in line.split(' ')] for line in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int.get(word, target_vocab_to_int['<UNK>']) for word in line.split(' ') + ['<EOS>']] for line in target_text.split('\n')]

    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# C:\Anaconda3\envs\dlnd\lib\site-packages\ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None])
    learning_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return (inputs, targets, learning_rate, keep_prob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    def build_nn(rnn_size):
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        dropout_lstm = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob=0.5)
#         lstm = tf.nn.dropout(lstm, keep_prob=keep_prob)
        return dropout_lstm
    cells = tf.contrib.rnn.MultiRNNCell([build_nn(rnn_size) for _ in range(num_layers)])
    _, rnnstate = tf.nn.dynamic_rnn(cells, rnn_inputs, dtype=tf.float32)
    return rnnstate

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function

    # Training Decoder
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    
    # Apply output function
    train_logits =  output_fn(train_pred)
    
    train_logits = tf.nn.dropout(train_logits, keep_prob)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length - 1, vocab_size)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    inference_logits = tf.nn.dropout(inference_logits, keep_prob)
    return inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    
    # Decoder RNNs
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size) for _ in range(num_layers)])
    start_of_sequence_id = target_vocab_to_int['<GO>']
    end_of_sequence_id = target_vocab_to_int['<EOS>']
    # Output Layer
    with tf.variable_scope("decoding") as decoding_scope:
        # fully-connected layer
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        # decode-train
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)
    with tf.variable_scope("decoding", reuse="True") as decoding_scope:
        # decode-infer
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, sequence_length-1, vocab_size, decoding_scope, output_fn, keep_prob)
    
    return train_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    rnn_inputs = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoder_state = encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    train_logits, infer_logits = decoding_layer(dec_embed_input, dec_embeddings, encoder_state, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    return (train_logits, infer_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 500
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 200
decoding_embedding_size = 200
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/275 - Train Accuracy:  0.242, Validation Accuracy:  0.310, Loss:  5.917
# Epoch   0 Batch    1/275 - Train Accuracy:  0.268, Validation Accuracy:  0.340, Loss:  6.472
# Epoch   0 Batch    2/275 - Train Accuracy:  0.246, Validation Accuracy:  0.289, Loss:  5.576
# Epoch   0 Batch    3/275 - Train Accuracy:  0.234, Validation Accuracy:  0.305, Loss:  5.087
# Epoch   0 Batch    4/275 - Train Accuracy:  0.240, Validation Accuracy:  0.309, Loss:  4.976
# Epoch   0 Batch    5/275 - Train Accuracy:  0.246, Validation Accuracy:  0.313, Loss:  4.861
# Epoch   0 Batch    6/275 - Train Accuracy:  0.318, Validation Accuracy:  0.347, Loss:  4.730
# Epoch   0 Batch    7/275 - Train Accuracy:  0.319, Validation Accuracy:  0.350, Loss:  4.656
# Epoch   0 Batch    8/275 - Train Accuracy:  0.281, Validation Accuracy:  0.347, Loss:  4.653
# Epoch   0 Batch    9/275 - Train Accuracy:  0.311, Validation Accuracy:  0.350, Loss:  4.590
# Epoch   0 Batch   10/275 - Train Accuracy:  0.276, Validation Accuracy:  0.350, Loss:  4.618
# Epoch   0 Batch   11/275 - Train Accuracy:  0.324, Validation Accuracy:  0.350, Loss:  4.480
# Epoch   0 Batch   12/275 - Train Accuracy:  0.294, Validation Accuracy:  0.356, Loss:  4.506
# Epoch   0 Batch   13/275 - Train Accuracy:  0.358, Validation Accuracy:  0.360, Loss:  4.347
# Epoch   0 Batch   14/275 - Train Accuracy:  0.336, Validation Accuracy:  0.377, Loss:  4.387
# Epoch   0 Batch   15/275 - Train Accuracy:  0.355, Validation Accuracy:  0.389, Loss:  4.362
# Epoch   0 Batch   16/275 - Train Accuracy:  0.347, Validation Accuracy:  0.387, Loss:  4.311
# Epoch   0 Batch   17/275 - Train Accuracy:  0.336, Validation Accuracy:  0.398, Loss:  4.344
# Epoch   0 Batch   18/275 - Train Accuracy:  0.367, Validation Accuracy:  0.397, Loss:  4.238
# Epoch   0 Batch   19/275 - Train Accuracy:  0.344, Validation Accuracy:  0.407, Loss:  4.295
# Epoch   0 Batch   20/275 - Train Accuracy:  0.419, Validation Accuracy:  0.418, Loss:  4.159
# Epoch   0 Batch   21/275 - Train Accuracy:  0.384, Validation Accuracy:  0.429, Loss:  4.209
# Epoch   0 Batch   22/275 - Train Accuracy:  0.387, Validation Accuracy:  0.419, Loss:  4.192
# Epoch   0 Batch   23/275 - Train Accuracy:  0.392, Validation Accuracy:  0.416, Loss:  4.155
# Epoch   0 Batch   24/275 - Train Accuracy:  0.392, Validation Accuracy:  0.413, Loss:  4.118
# Epoch   0 Batch   25/275 - Train Accuracy:  0.384, Validation Accuracy:  0.441, Loss:  4.193
# Epoch   0 Batch   26/275 - Train Accuracy:  0.427, Validation Accuracy:  0.453, Loss:  4.102
# Epoch   0 Batch   27/275 - Train Accuracy:  0.453, Validation Accuracy:  0.452, Loss:  4.003
# Epoch   0 Batch   28/275 - Train Accuracy:  0.439, Validation Accuracy:  0.468, Loss:  4.076
# Epoch   0 Batch   29/275 - Train Accuracy:  0.399, Validation Accuracy:  0.466, Loss:  4.148
# Epoch   0 Batch   30/275 - Train Accuracy:  0.405, Validation Accuracy:  0.460, Loss:  4.102
# Epoch   0 Batch   31/275 - Train Accuracy:  0.435, Validation Accuracy:  0.466, Loss:  4.036
# Epoch   0 Batch   32/275 - Train Accuracy:  0.448, Validation Accuracy:  0.473, Loss:  4.013
# Epoch   0 Batch   33/275 - Train Accuracy:  0.464, Validation Accuracy:  0.488, Loss:  3.982
# Epoch   0 Batch   34/275 - Train Accuracy:  0.461, Validation Accuracy:  0.481, Loss:  3.962
# Epoch   0 Batch   35/275 - Train Accuracy:  0.458, Validation Accuracy:  0.484, Loss:  3.987
# Epoch   0 Batch   36/275 - Train Accuracy:  0.470, Validation Accuracy:  0.489, Loss:  3.964
# Epoch   0 Batch   37/275 - Train Accuracy:  0.469, Validation Accuracy:  0.497, Loss:  3.927
# Epoch   0 Batch   38/275 - Train Accuracy:  0.473, Validation Accuracy:  0.496, Loss:  3.941
# Epoch   0 Batch   39/275 - Train Accuracy:  0.473, Validation Accuracy:  0.495, Loss:  3.917
# Epoch   0 Batch   40/275 - Train Accuracy:  0.486, Validation Accuracy:  0.512, Loss:  3.874
# Epoch   0 Batch   41/275 - Train Accuracy:  0.467, Validation Accuracy:  0.511, Loss:  3.945
# Epoch   0 Batch   42/275 - Train Accuracy:  0.489, Validation Accuracy:  0.513, Loss:  3.896
# Epoch   0 Batch   43/275 - Train Accuracy:  0.513, Validation Accuracy:  0.521, Loss:  3.801
# Epoch   0 Batch   44/275 - Train Accuracy:  0.469, Validation Accuracy:  0.508, Loss:  3.903
# Epoch   0 Batch   45/275 - Train Accuracy:  0.505, Validation Accuracy:  0.520, Loss:  3.854
# Epoch   0 Batch   46/275 - Train Accuracy:  0.487, Validation Accuracy:  0.530, Loss:  3.888
# Epoch   0 Batch   47/275 - Train Accuracy:  0.459, Validation Accuracy:  0.513, Loss:  3.849
# Epoch   0 Batch   48/275 - Train Accuracy:  0.531, Validation Accuracy:  0.526, Loss:  3.762
# Epoch   0 Batch   49/275 - Train Accuracy:  0.502, Validation Accuracy:  0.519, Loss:  3.819
# Epoch   0 Batch   50/275 - Train Accuracy:  0.508, Validation Accuracy:  0.526, Loss:  3.783
# Epoch   0 Batch   51/275 - Train Accuracy:  0.484, Validation Accuracy:  0.528, Loss:  3.805
# Epoch   0 Batch   52/275 - Train Accuracy:  0.502, Validation Accuracy:  0.528, Loss:  3.828
# Epoch   0 Batch   53/275 - Train Accuracy:  0.508, Validation Accuracy:  0.533, Loss:  3.770
# Epoch   0 Batch   54/275 - Train Accuracy:  0.492, Validation Accuracy:  0.544, Loss:  3.803
# Epoch   0 Batch   55/275 - Train Accuracy:  0.529, Validation Accuracy:  0.551, Loss:  3.746
# Epoch   0 Batch   56/275 - Train Accuracy:  0.513, Validation Accuracy:  0.534, Loss:  3.692
# Epoch   0 Batch   57/275 - Train Accuracy:  0.507, Validation Accuracy:  0.553, Loss:  3.778
# Epoch   0 Batch   58/275 - Train Accuracy:  0.540, Validation Accuracy:  0.553, Loss:  3.676
# Epoch   0 Batch   59/275 - Train Accuracy:  0.519, Validation Accuracy:  0.543, Loss:  3.674
# Epoch   0 Batch   60/275 - Train Accuracy:  0.542, Validation Accuracy:  0.557, Loss:  3.686
# Epoch   0 Batch   61/275 - Train Accuracy:  0.554, Validation Accuracy:  0.558, Loss:  3.579
# Epoch   0 Batch   62/275 - Train Accuracy:  0.542, Validation Accuracy:  0.552, Loss:  3.647
# Epoch   0 Batch   63/275 - Train Accuracy:  0.558, Validation Accuracy:  0.564, Loss:  3.596
# Epoch   0 Batch   64/275 - Train Accuracy:  0.561, Validation Accuracy:  0.564, Loss:  3.608
# Epoch   0 Batch   65/275 - Train Accuracy:  0.535, Validation Accuracy:  0.557, Loss:  3.635
# Epoch   0 Batch   66/275 - Train Accuracy:  0.546, Validation Accuracy:  0.569, Loss:  3.551
# Epoch   0 Batch   67/275 - Train Accuracy:  0.558, Validation Accuracy:  0.554, Loss:  3.567
# Epoch   0 Batch   68/275 - Train Accuracy:  0.533, Validation Accuracy:  0.574, Loss:  3.630
# Epoch   0 Batch   69/275 - Train Accuracy:  0.541, Validation Accuracy:  0.562, Loss:  3.536
# Epoch   0 Batch   70/275 - Train Accuracy:  0.548, Validation Accuracy:  0.568, Loss:  3.603
# Epoch   0 Batch   71/275 - Train Accuracy:  0.534, Validation Accuracy:  0.565, Loss:  3.555
# Epoch   0 Batch   72/275 - Train Accuracy:  0.569, Validation Accuracy:  0.570, Loss:  3.516
# Epoch   0 Batch   73/275 - Train Accuracy:  0.549, Validation Accuracy:  0.566, Loss:  3.511
# Epoch   0 Batch   74/275 - Train Accuracy:  0.581, Validation Accuracy:  0.573, Loss:  3.481
# Epoch   0 Batch   75/275 - Train Accuracy:  0.555, Validation Accuracy:  0.575, Loss:  3.501
# Epoch   0 Batch   76/275 - Train Accuracy:  0.547, Validation Accuracy:  0.577, Loss:  3.538
# Epoch   0 Batch   77/275 - Train Accuracy:  0.554, Validation Accuracy:  0.573, Loss:  3.422
# Epoch   0 Batch   78/275 - Train Accuracy:  0.550, Validation Accuracy:  0.576, Loss:  3.498
# Epoch   0 Batch   79/275 - Train Accuracy:  0.555, Validation Accuracy:  0.564, Loss:  3.442
# Epoch   0 Batch   80/275 - Train Accuracy:  0.547, Validation Accuracy:  0.563, Loss:  3.409
# Epoch   0 Batch   81/275 - Train Accuracy:  0.544, Validation Accuracy:  0.566, Loss:  3.422
# Epoch   0 Batch   82/275 - Train Accuracy:  0.567, Validation Accuracy:  0.567, Loss:  3.375
# Epoch   0 Batch   83/275 - Train Accuracy:  0.548, Validation Accuracy:  0.562, Loss:  3.423
# Epoch   0 Batch   84/275 - Train Accuracy:  0.550, Validation Accuracy:  0.550, Loss:  3.393
# Epoch   0 Batch   85/275 - Train Accuracy:  0.541, Validation Accuracy:  0.551, Loss:  3.315
# Epoch   0 Batch   86/275 - Train Accuracy:  0.542, Validation Accuracy:  0.554, Loss:  3.341
# Epoch   0 Batch   87/275 - Train Accuracy:  0.538, Validation Accuracy:  0.553, Loss:  3.340
# Epoch   0 Batch   88/275 - Train Accuracy:  0.531, Validation Accuracy:  0.551, Loss:  3.334
# Epoch   0 Batch   89/275 - Train Accuracy:  0.506, Validation Accuracy:  0.547, Loss:  3.369
# Epoch   0 Batch   90/275 - Train Accuracy:  0.542, Validation Accuracy:  0.550, Loss:  3.298
# Epoch   0 Batch   91/275 - Train Accuracy:  0.549, Validation Accuracy:  0.549, Loss:  3.244
# Epoch   0 Batch   92/275 - Train Accuracy:  0.502, Validation Accuracy:  0.557, Loss:  3.343
# Epoch   0 Batch   93/275 - Train Accuracy:  0.548, Validation Accuracy:  0.558, Loss:  3.247
# Epoch   0 Batch   94/275 - Train Accuracy:  0.549, Validation Accuracy:  0.558, Loss:  3.279
# Epoch   0 Batch   95/275 - Train Accuracy:  0.555, Validation Accuracy:  0.562, Loss:  3.257
# Epoch   0 Batch   96/275 - Train Accuracy:  0.532, Validation Accuracy:  0.570, Loss:  3.251
# Epoch   0 Batch   97/275 - Train Accuracy:  0.546, Validation Accuracy:  0.560, Loss:  3.238
# Epoch   0 Batch   98/275 - Train Accuracy:  0.555, Validation Accuracy:  0.564, Loss:  3.175
# Epoch   0 Batch   99/275 - Train Accuracy:  0.550, Validation Accuracy:  0.572, Loss:  3.193
# Epoch   0 Batch  100/275 - Train Accuracy:  0.553, Validation Accuracy:  0.569, Loss:  3.219
# Epoch   0 Batch  101/275 - Train Accuracy:  0.549, Validation Accuracy:  0.570, Loss:  3.271
# Epoch   0 Batch  102/275 - Train Accuracy:  0.561, Validation Accuracy:  0.568, Loss:  3.156
# Epoch   0 Batch  103/275 - Train Accuracy:  0.536, Validation Accuracy:  0.571, Loss:  3.236
# Epoch   0 Batch  104/275 - Train Accuracy:  0.552, Validation Accuracy:  0.574, Loss:  3.175
# Epoch   0 Batch  105/275 - Train Accuracy:  0.560, Validation Accuracy:  0.577, Loss:  3.167
# Epoch   0 Batch  106/275 - Train Accuracy:  0.555, Validation Accuracy:  0.583, Loss:  3.195
# Epoch   0 Batch  107/275 - Train Accuracy:  0.564, Validation Accuracy:  0.582, Loss:  3.196
# Epoch   0 Batch  108/275 - Train Accuracy:  0.550, Validation Accuracy:  0.580, Loss:  3.197
# Epoch   0 Batch  109/275 - Train Accuracy:  0.557, Validation Accuracy:  0.579, Loss:  3.132
# Epoch   0 Batch  110/275 - Train Accuracy:  0.564, Validation Accuracy:  0.577, Loss:  3.139
# Epoch   0 Batch  111/275 - Train Accuracy:  0.551, Validation Accuracy:  0.578, Loss:  3.132
# Epoch   0 Batch  112/275 - Train Accuracy:  0.554, Validation Accuracy:  0.583, Loss:  3.138
# Epoch   0 Batch  113/275 - Train Accuracy:  0.559, Validation Accuracy:  0.582, Loss:  3.188
# Epoch   0 Batch  114/275 - Train Accuracy:  0.556, Validation Accuracy:  0.578, Loss:  3.140
# Epoch   0 Batch  115/275 - Train Accuracy:  0.583, Validation Accuracy:  0.578, Loss:  3.178
# Epoch   0 Batch  116/275 - Train Accuracy:  0.564, Validation Accuracy:  0.579, Loss:  3.167
# Epoch   0 Batch  117/275 - Train Accuracy:  0.543, Validation Accuracy:  0.591, Loss:  3.124
# Epoch   0 Batch  118/275 - Train Accuracy:  0.587, Validation Accuracy:  0.578, Loss:  3.108
# Epoch   0 Batch  119/275 - Train Accuracy:  0.556, Validation Accuracy:  0.590, Loss:  3.134
# Epoch   0 Batch  120/275 - Train Accuracy:  0.564, Validation Accuracy:  0.593, Loss:  3.100
# Epoch   0 Batch  121/275 - Train Accuracy:  0.588, Validation Accuracy:  0.588, Loss:  3.082
# Epoch   0 Batch  122/275 - Train Accuracy:  0.565, Validation Accuracy:  0.588, Loss:  3.137
# Epoch   0 Batch  123/275 - Train Accuracy:  0.551, Validation Accuracy:  0.583, Loss:  3.151
# Epoch   0 Batch  124/275 - Train Accuracy:  0.576, Validation Accuracy:  0.589, Loss:  3.109
# Epoch   0 Batch  125/275 - Train Accuracy:  0.578, Validation Accuracy:  0.591, Loss:  3.077
# Epoch   0 Batch  126/275 - Train Accuracy:  0.555, Validation Accuracy:  0.589, Loss:  3.101
# Epoch   0 Batch  127/275 - Train Accuracy:  0.570, Validation Accuracy:  0.583, Loss:  3.132
# Epoch   0 Batch  128/275 - Train Accuracy:  0.576, Validation Accuracy:  0.589, Loss:  3.143
# Epoch   0 Batch  129/275 - Train Accuracy:  0.587, Validation Accuracy:  0.602, Loss:  3.105
# Epoch   0 Batch  130/275 - Train Accuracy:  0.586, Validation Accuracy:  0.605, Loss:  3.113
# Epoch   0 Batch  131/275 - Train Accuracy:  0.604, Validation Accuracy:  0.600, Loss:  3.087
# Epoch   0 Batch  132/275 - Train Accuracy:  0.592, Validation Accuracy:  0.599, Loss:  3.090
# Epoch   0 Batch  133/275 - Train Accuracy:  0.576, Validation Accuracy:  0.600, Loss:  3.102
# Epoch   0 Batch  134/275 - Train Accuracy:  0.575, Validation Accuracy:  0.601, Loss:  3.051
# Epoch   0 Batch  135/275 - Train Accuracy:  0.558, Validation Accuracy:  0.593, Loss:  3.110
# Epoch   0 Batch  136/275 - Train Accuracy:  0.582, Validation Accuracy:  0.591, Loss:  3.094
# Epoch   0 Batch  137/275 - Train Accuracy:  0.589, Validation Accuracy:  0.595, Loss:  3.071
# Epoch   0 Batch  138/275 - Train Accuracy:  0.573, Validation Accuracy:  0.606, Loss:  3.102
# Epoch   0 Batch  139/275 - Train Accuracy:  0.584, Validation Accuracy:  0.610, Loss:  3.121
# Epoch   0 Batch  140/275 - Train Accuracy:  0.581, Validation Accuracy:  0.609, Loss:  3.092
# Epoch   0 Batch  141/275 - Train Accuracy:  0.601, Validation Accuracy:  0.602, Loss:  3.094
# Epoch   0 Batch  142/275 - Train Accuracy:  0.602, Validation Accuracy:  0.600, Loss:  3.089
# Epoch   0 Batch  143/275 - Train Accuracy:  0.614, Validation Accuracy:  0.594, Loss:  3.048
# Epoch   0 Batch  144/275 - Train Accuracy:  0.612, Validation Accuracy:  0.601, Loss:  3.031
# Epoch   0 Batch  145/275 - Train Accuracy:  0.609, Validation Accuracy:  0.603, Loss:  3.057
# Epoch   0 Batch  146/275 - Train Accuracy:  0.622, Validation Accuracy:  0.615, Loss:  3.045
# Epoch   0 Batch  147/275 - Train Accuracy:  0.606, Validation Accuracy:  0.613, Loss:  3.063
# Epoch   0 Batch  148/275 - Train Accuracy:  0.611, Validation Accuracy:  0.623, Loss:  3.033
# Epoch   0 Batch  149/275 - Train Accuracy:  0.604, Validation Accuracy:  0.622, Loss:  3.037
# Epoch   0 Batch  150/275 - Train Accuracy:  0.624, Validation Accuracy:  0.610, Loss:  3.041
# Epoch   0 Batch  151/275 - Train Accuracy:  0.600, Validation Accuracy:  0.620, Loss:  3.037
# Epoch   0 Batch  152/275 - Train Accuracy:  0.601, Validation Accuracy:  0.623, Loss:  3.020
# Epoch   0 Batch  153/275 - Train Accuracy:  0.591, Validation Accuracy:  0.615, Loss:  3.063
# Epoch   0 Batch  154/275 - Train Accuracy:  0.652, Validation Accuracy:  0.618, Loss:  2.963
# Epoch   0 Batch  155/275 - Train Accuracy:  0.592, Validation Accuracy:  0.623, Loss:  3.047
# Epoch   0 Batch  156/275 - Train Accuracy:  0.621, Validation Accuracy:  0.625, Loss:  3.034
# Epoch   0 Batch  157/275 - Train Accuracy:  0.627, Validation Accuracy:  0.621, Loss:  3.039
# Epoch   0 Batch  158/275 - Train Accuracy:  0.608, Validation Accuracy:  0.633, Loss:  3.074
# Epoch   0 Batch  159/275 - Train Accuracy:  0.649, Validation Accuracy:  0.623, Loss:  2.971
# Epoch   0 Batch  160/275 - Train Accuracy:  0.618, Validation Accuracy:  0.632, Loss:  3.013
# Epoch   0 Batch  161/275 - Train Accuracy:  0.614, Validation Accuracy:  0.628, Loss:  3.042
# Epoch   0 Batch  162/275 - Train Accuracy:  0.624, Validation Accuracy:  0.623, Loss:  3.005
# Epoch   0 Batch  163/275 - Train Accuracy:  0.627, Validation Accuracy:  0.630, Loss:  2.994
# Epoch   0 Batch  164/275 - Train Accuracy:  0.629, Validation Accuracy:  0.625, Loss:  3.053
# Epoch   0 Batch  165/275 - Train Accuracy:  0.616, Validation Accuracy:  0.631, Loss:  3.050
# Epoch   0 Batch  166/275 - Train Accuracy:  0.631, Validation Accuracy:  0.627, Loss:  3.023
# Epoch   0 Batch  167/275 - Train Accuracy:  0.637, Validation Accuracy:  0.619, Loss:  3.027
# Epoch   0 Batch  168/275 - Train Accuracy:  0.626, Validation Accuracy:  0.624, Loss:  2.972
# Epoch   0 Batch  169/275 - Train Accuracy:  0.616, Validation Accuracy:  0.625, Loss:  2.978
# Epoch   0 Batch  170/275 - Train Accuracy:  0.638, Validation Accuracy:  0.632, Loss:  2.970
# Epoch   0 Batch  171/275 - Train Accuracy:  0.630, Validation Accuracy:  0.624, Loss:  2.970
# Epoch   0 Batch  172/275 - Train Accuracy:  0.625, Validation Accuracy:  0.630, Loss:  3.006
# Epoch   0 Batch  173/275 - Train Accuracy:  0.638, Validation Accuracy:  0.635, Loss:  3.016
# Epoch   0 Batch  174/275 - Train Accuracy:  0.626, Validation Accuracy:  0.629, Loss:  3.024
# Epoch   0 Batch  175/275 - Train Accuracy:  0.614, Validation Accuracy:  0.626, Loss:  3.031
# Epoch   0 Batch  176/275 - Train Accuracy:  0.624, Validation Accuracy:  0.620, Loss:  3.028
# Epoch   0 Batch  177/275 - Train Accuracy:  0.634, Validation Accuracy:  0.616, Loss:  2.984
# Epoch   0 Batch  178/275 - Train Accuracy:  0.614, Validation Accuracy:  0.622, Loss:  2.987
# Epoch   0 Batch  179/275 - Train Accuracy:  0.638, Validation Accuracy:  0.624, Loss:  3.031
# Epoch   0 Batch  180/275 - Train Accuracy:  0.643, Validation Accuracy:  0.638, Loss:  3.001
# Epoch   0 Batch  181/275 - Train Accuracy:  0.652, Validation Accuracy:  0.626, Loss:  2.957
# Epoch   0 Batch  182/275 - Train Accuracy:  0.638, Validation Accuracy:  0.635, Loss:  2.994
# Epoch   0 Batch  183/275 - Train Accuracy:  0.642, Validation Accuracy:  0.647, Loss:  3.002
# Epoch   0 Batch  184/275 - Train Accuracy:  0.647, Validation Accuracy:  0.638, Loss:  2.962
# Epoch   0 Batch  185/275 - Train Accuracy:  0.648, Validation Accuracy:  0.644, Loss:  3.001
# Epoch   0 Batch  186/275 - Train Accuracy:  0.635, Validation Accuracy:  0.641, Loss:  2.948
# Epoch   0 Batch  187/275 - Train Accuracy:  0.643, Validation Accuracy:  0.632, Loss:  2.994
# Epoch   0 Batch  188/275 - Train Accuracy:  0.686, Validation Accuracy:  0.642, Loss:  2.900
# Epoch   0 Batch  189/275 - Train Accuracy:  0.657, Validation Accuracy:  0.644, Loss:  2.968
# Epoch   0 Batch  190/275 - Train Accuracy:  0.646, Validation Accuracy:  0.642, Loss:  2.988
# Epoch   0 Batch  191/275 - Train Accuracy:  0.633, Validation Accuracy:  0.627, Loss:  2.933
# Epoch   0 Batch  192/275 - Train Accuracy:  0.625, Validation Accuracy:  0.632, Loss:  2.992
# Epoch   0 Batch  193/275 - Train Accuracy:  0.645, Validation Accuracy:  0.636, Loss:  2.975
# Epoch   0 Batch  194/275 - Train Accuracy:  0.634, Validation Accuracy:  0.639, Loss:  2.940
# Epoch   0 Batch  195/275 - Train Accuracy:  0.624, Validation Accuracy:  0.635, Loss:  3.013
# Epoch   0 Batch  196/275 - Train Accuracy:  0.650, Validation Accuracy:  0.635, Loss:  2.980
# Epoch   0 Batch  197/275 - Train Accuracy:  0.641, Validation Accuracy:  0.643, Loss:  2.981
# Epoch   0 Batch  198/275 - Train Accuracy:  0.661, Validation Accuracy:  0.634, Loss:  2.961
# Epoch   0 Batch  199/275 - Train Accuracy:  0.645, Validation Accuracy:  0.644, Loss:  2.902
# Epoch   0 Batch  200/275 - Train Accuracy:  0.647, Validation Accuracy:  0.644, Loss:  2.974
# Epoch   0 Batch  201/275 - Train Accuracy:  0.603, Validation Accuracy:  0.632, Loss:  2.958
# Epoch   0 Batch  202/275 - Train Accuracy:  0.617, Validation Accuracy:  0.645, Loss:  2.987
# Epoch   0 Batch  203/275 - Train Accuracy:  0.634, Validation Accuracy:  0.648, Loss:  2.974
# Epoch   0 Batch  204/275 - Train Accuracy:  0.633, Validation Accuracy:  0.647, Loss:  2.947
# Epoch   0 Batch  205/275 - Train Accuracy:  0.628, Validation Accuracy:  0.643, Loss:  2.960
# Epoch   0 Batch  206/275 - Train Accuracy:  0.654, Validation Accuracy:  0.652, Loss:  2.952
# Epoch   0 Batch  207/275 - Train Accuracy:  0.654, Validation Accuracy:  0.662, Loss:  2.952
# Epoch   0 Batch  208/275 - Train Accuracy:  0.639, Validation Accuracy:  0.658, Loss:  2.960
# Epoch   0 Batch  209/275 - Train Accuracy:  0.637, Validation Accuracy:  0.654, Loss:  2.972
# Epoch   0 Batch  210/275 - Train Accuracy:  0.666, Validation Accuracy:  0.650, Loss:  2.925
# Epoch   0 Batch  211/275 - Train Accuracy:  0.647, Validation Accuracy:  0.651, Loss:  2.965
# Epoch   0 Batch  212/275 - Train Accuracy:  0.666, Validation Accuracy:  0.647, Loss:  2.917
# Epoch   0 Batch  213/275 - Train Accuracy:  0.642, Validation Accuracy:  0.653, Loss:  2.951
# Epoch   0 Batch  214/275 - Train Accuracy:  0.649, Validation Accuracy:  0.656, Loss:  2.947
# Epoch   0 Batch  215/275 - Train Accuracy:  0.646, Validation Accuracy:  0.655, Loss:  2.883
# Epoch   0 Batch  216/275 - Train Accuracy:  0.651, Validation Accuracy:  0.668, Loss:  2.953
# Epoch   0 Batch  217/275 - Train Accuracy:  0.668, Validation Accuracy:  0.666, Loss:  2.944
# Epoch   0 Batch  218/275 - Train Accuracy:  0.658, Validation Accuracy:  0.667, Loss:  2.969
# Epoch   0 Batch  219/275 - Train Accuracy:  0.664, Validation Accuracy:  0.671, Loss:  2.937
# Epoch   0 Batch  220/275 - Train Accuracy:  0.695, Validation Accuracy:  0.658, Loss:  2.899
# Epoch   0 Batch  221/275 - Train Accuracy:  0.657, Validation Accuracy:  0.657, Loss:  2.946
# Epoch   0 Batch  222/275 - Train Accuracy:  0.631, Validation Accuracy:  0.654, Loss:  2.950
# Epoch   0 Batch  223/275 - Train Accuracy:  0.634, Validation Accuracy:  0.655, Loss:  2.957
# Epoch   0 Batch  224/275 - Train Accuracy:  0.643, Validation Accuracy:  0.651, Loss:  2.915
# Epoch   0 Batch  225/275 - Train Accuracy:  0.675, Validation Accuracy:  0.655, Loss:  2.898
# Epoch   0 Batch  226/275 - Train Accuracy:  0.664, Validation Accuracy:  0.659, Loss:  2.950
# Epoch   0 Batch  227/275 - Train Accuracy:  0.694, Validation Accuracy:  0.653, Loss:  2.926
# Epoch   0 Batch  228/275 - Train Accuracy:  0.665, Validation Accuracy:  0.657, Loss:  2.851
# Epoch   0 Batch  229/275 - Train Accuracy:  0.669, Validation Accuracy:  0.657, Loss:  2.923
# Epoch   0 Batch  230/275 - Train Accuracy:  0.667, Validation Accuracy:  0.659, Loss:  2.902
# Epoch   0 Batch  231/275 - Train Accuracy:  0.658, Validation Accuracy:  0.667, Loss:  2.974
# Epoch   0 Batch  232/275 - Train Accuracy:  0.683, Validation Accuracy:  0.670, Loss:  2.915
# Epoch   0 Batch  233/275 - Train Accuracy:  0.701, Validation Accuracy:  0.671, Loss:  2.913
# Epoch   0 Batch  234/275 - Train Accuracy:  0.676, Validation Accuracy:  0.668, Loss:  2.932
# Epoch   0 Batch  235/275 - Train Accuracy:  0.667, Validation Accuracy:  0.667, Loss:  2.945
# Epoch   0 Batch  236/275 - Train Accuracy:  0.655, Validation Accuracy:  0.678, Loss:  2.881
# Epoch   0 Batch  237/275 - Train Accuracy:  0.680, Validation Accuracy:  0.680, Loss:  2.950
# Epoch   0 Batch  238/275 - Train Accuracy:  0.655, Validation Accuracy:  0.680, Loss:  2.887
# Epoch   0 Batch  239/275 - Train Accuracy:  0.700, Validation Accuracy:  0.680, Loss:  2.913
# Epoch   0 Batch  240/275 - Train Accuracy:  0.667, Validation Accuracy:  0.665, Loss:  2.900
# Epoch   0 Batch  241/275 - Train Accuracy:  0.683, Validation Accuracy:  0.675, Loss:  2.870
# Epoch   0 Batch  242/275 - Train Accuracy:  0.664, Validation Accuracy:  0.670, Loss:  2.882
# Epoch   0 Batch  243/275 - Train Accuracy:  0.671, Validation Accuracy:  0.681, Loss:  2.952
# Epoch   0 Batch  244/275 - Train Accuracy:  0.696, Validation Accuracy:  0.679, Loss:  2.918
# Epoch   0 Batch  245/275 - Train Accuracy:  0.685, Validation Accuracy:  0.678, Loss:  2.878
# Epoch   0 Batch  246/275 - Train Accuracy:  0.709, Validation Accuracy:  0.693, Loss:  2.907
# Epoch   0 Batch  247/275 - Train Accuracy:  0.685, Validation Accuracy:  0.688, Loss:  2.886
# Epoch   0 Batch  248/275 - Train Accuracy:  0.679, Validation Accuracy:  0.686, Loss:  2.853
# Epoch   0 Batch  249/275 - Train Accuracy:  0.703, Validation Accuracy:  0.683, Loss:  2.875
# Epoch   0 Batch  250/275 - Train Accuracy:  0.679, Validation Accuracy:  0.681, Loss:  2.909
# Epoch   0 Batch  251/275 - Train Accuracy:  0.657, Validation Accuracy:  0.684, Loss:  2.961
# Epoch   0 Batch  252/275 - Train Accuracy:  0.678, Validation Accuracy:  0.680, Loss:  2.893
# Epoch   0 Batch  253/275 - Train Accuracy:  0.666, Validation Accuracy:  0.684, Loss:  2.929
# Epoch   0 Batch  254/275 - Train Accuracy:  0.693, Validation Accuracy:  0.685, Loss:  2.853
# Epoch   0 Batch  255/275 - Train Accuracy:  0.696, Validation Accuracy:  0.694, Loss:  2.868
# Epoch   0 Batch  256/275 - Train Accuracy:  0.694, Validation Accuracy:  0.694, Loss:  2.923
# Epoch   0 Batch  257/275 - Train Accuracy:  0.717, Validation Accuracy:  0.703, Loss:  2.871
# Epoch   0 Batch  258/275 - Train Accuracy:  0.689, Validation Accuracy:  0.689, Loss:  2.907
# Epoch   0 Batch  259/275 - Train Accuracy:  0.669, Validation Accuracy:  0.693, Loss:  2.874
# Epoch   0 Batch  260/275 - Train Accuracy:  0.681, Validation Accuracy:  0.686, Loss:  2.923
# Epoch   0 Batch  261/275 - Train Accuracy:  0.702, Validation Accuracy:  0.681, Loss:  2.869
# Epoch   0 Batch  262/275 - Train Accuracy:  0.677, Validation Accuracy:  0.686, Loss:  2.910
# Epoch   0 Batch  263/275 - Train Accuracy:  0.684, Validation Accuracy:  0.684, Loss:  2.880
# Epoch   0 Batch  264/275 - Train Accuracy:  0.694, Validation Accuracy:  0.689, Loss:  2.877
# Epoch   0 Batch  265/275 - Train Accuracy:  0.709, Validation Accuracy:  0.700, Loss:  2.838
# Epoch   0 Batch  266/275 - Train Accuracy:  0.688, Validation Accuracy:  0.699, Loss:  2.862
# Epoch   0 Batch  267/275 - Train Accuracy:  0.681, Validation Accuracy:  0.690, Loss:  2.886
# Epoch   0 Batch  268/275 - Train Accuracy:  0.699, Validation Accuracy:  0.690, Loss:  2.879
# Epoch   0 Batch  269/275 - Train Accuracy:  0.699, Validation Accuracy:  0.708, Loss:  2.851
# Epoch   0 Batch  270/275 - Train Accuracy:  0.694, Validation Accuracy:  0.704, Loss:  2.871
# Epoch   0 Batch  271/275 - Train Accuracy:  0.686, Validation Accuracy:  0.699, Loss:  2.897
# Epoch   0 Batch  272/275 - Train Accuracy:  0.690, Validation Accuracy:  0.700, Loss:  2.883
# Epoch   0 Batch  273/275 - Train Accuracy:  0.695, Validation Accuracy:  0.697, Loss:  2.899
# Epoch   1 Batch    0/275 - Train Accuracy:  0.712, Validation Accuracy:  0.703, Loss:  2.873
# Epoch   1 Batch    1/275 - Train Accuracy:  0.700, Validation Accuracy:  0.698, Loss:  2.871
# Epoch   1 Batch    2/275 - Train Accuracy:  0.705, Validation Accuracy:  0.707, Loss:  2.866
# Epoch   1 Batch    3/275 - Train Accuracy:  0.720, Validation Accuracy:  0.711, Loss:  2.865
# Epoch   1 Batch    4/275 - Train Accuracy:  0.688, Validation Accuracy:  0.715, Loss:  2.902
# Epoch   1 Batch    5/275 - Train Accuracy:  0.698, Validation Accuracy:  0.710, Loss:  2.857
# Epoch   1 Batch    6/275 - Train Accuracy:  0.710, Validation Accuracy:  0.709, Loss:  2.864
# Epoch   1 Batch    7/275 - Train Accuracy:  0.713, Validation Accuracy:  0.707, Loss:  2.844
# Epoch   1 Batch    8/275 - Train Accuracy:  0.712, Validation Accuracy:  0.708, Loss:  2.871
# Epoch   1 Batch    9/275 - Train Accuracy:  0.709, Validation Accuracy:  0.713, Loss:  2.839
# Epoch   1 Batch   10/275 - Train Accuracy:  0.718, Validation Accuracy:  0.714, Loss:  2.837
# Epoch   1 Batch   11/275 - Train Accuracy:  0.722, Validation Accuracy:  0.718, Loss:  2.861
# Epoch   1 Batch   12/275 - Train Accuracy:  0.709, Validation Accuracy:  0.722, Loss:  2.875
# Epoch   1 Batch   13/275 - Train Accuracy:  0.720, Validation Accuracy:  0.718, Loss:  2.871
# Epoch   1 Batch   14/275 - Train Accuracy:  0.709, Validation Accuracy:  0.721, Loss:  2.872
# Epoch   1 Batch   15/275 - Train Accuracy:  0.708, Validation Accuracy:  0.718, Loss:  2.833
# Epoch   1 Batch   16/275 - Train Accuracy:  0.721, Validation Accuracy:  0.724, Loss:  2.811
# Epoch   1 Batch   17/275 - Train Accuracy:  0.702, Validation Accuracy:  0.729, Loss:  2.860
# Epoch   1 Batch   18/275 - Train Accuracy:  0.744, Validation Accuracy:  0.733, Loss:  2.830
# Epoch   1 Batch   19/275 - Train Accuracy:  0.712, Validation Accuracy:  0.736, Loss:  2.849
# Epoch   1 Batch   20/275 - Train Accuracy:  0.749, Validation Accuracy:  0.734, Loss:  2.829
# Epoch   1 Batch   21/275 - Train Accuracy:  0.719, Validation Accuracy:  0.729, Loss:  2.871
# Epoch   1 Batch   22/275 - Train Accuracy:  0.722, Validation Accuracy:  0.733, Loss:  2.899
# Epoch   1 Batch   23/275 - Train Accuracy:  0.738, Validation Accuracy:  0.733, Loss:  2.847
# Epoch   1 Batch   24/275 - Train Accuracy:  0.737, Validation Accuracy:  0.727, Loss:  2.842
# Epoch   1 Batch   25/275 - Train Accuracy:  0.709, Validation Accuracy:  0.735, Loss:  2.868
# Epoch   1 Batch   26/275 - Train Accuracy:  0.723, Validation Accuracy:  0.734, Loss:  2.855
# Epoch   1 Batch   27/275 - Train Accuracy:  0.751, Validation Accuracy:  0.728, Loss:  2.812
# Epoch   1 Batch   28/275 - Train Accuracy:  0.732, Validation Accuracy:  0.740, Loss:  2.841
# Epoch   1 Batch   29/275 - Train Accuracy:  0.714, Validation Accuracy:  0.737, Loss:  2.805
# Epoch   1 Batch   30/275 - Train Accuracy:  0.747, Validation Accuracy:  0.746, Loss:  2.843
# Epoch   1 Batch   31/275 - Train Accuracy:  0.746, Validation Accuracy:  0.738, Loss:  2.821
# Epoch   1 Batch   32/275 - Train Accuracy:  0.750, Validation Accuracy:  0.745, Loss:  2.824
# Epoch   1 Batch   33/275 - Train Accuracy:  0.749, Validation Accuracy:  0.752, Loss:  2.825
# Epoch   1 Batch   34/275 - Train Accuracy:  0.747, Validation Accuracy:  0.739, Loss:  2.847
# Epoch   1 Batch   35/275 - Train Accuracy:  0.752, Validation Accuracy:  0.744, Loss:  2.807
# Epoch   1 Batch   36/275 - Train Accuracy:  0.756, Validation Accuracy:  0.742, Loss:  2.834
# Epoch   1 Batch   37/275 - Train Accuracy:  0.752, Validation Accuracy:  0.750, Loss:  2.795
# Epoch   1 Batch   38/275 - Train Accuracy:  0.770, Validation Accuracy:  0.758, Loss:  2.807
# Epoch   1 Batch   39/275 - Train Accuracy:  0.756, Validation Accuracy:  0.753, Loss:  2.871
# Epoch   1 Batch   40/275 - Train Accuracy:  0.756, Validation Accuracy:  0.746, Loss:  2.787
# Epoch   1 Batch   41/275 - Train Accuracy:  0.742, Validation Accuracy:  0.757, Loss:  2.823
# Epoch   1 Batch   42/275 - Train Accuracy:  0.747, Validation Accuracy:  0.755, Loss:  2.834
# Epoch   1 Batch   43/275 - Train Accuracy:  0.775, Validation Accuracy:  0.751, Loss:  2.812
# Epoch   1 Batch   44/275 - Train Accuracy:  0.757, Validation Accuracy:  0.751, Loss:  2.837
# Epoch   1 Batch   45/275 - Train Accuracy:  0.744, Validation Accuracy:  0.748, Loss:  2.813
# Epoch   1 Batch   46/275 - Train Accuracy:  0.748, Validation Accuracy:  0.758, Loss:  2.827
# Epoch   1 Batch   47/275 - Train Accuracy:  0.743, Validation Accuracy:  0.757, Loss:  2.798
# Epoch   1 Batch   48/275 - Train Accuracy:  0.787, Validation Accuracy:  0.762, Loss:  2.776
# Epoch   1 Batch   49/275 - Train Accuracy:  0.769, Validation Accuracy:  0.778, Loss:  2.804
# Epoch   1 Batch   50/275 - Train Accuracy:  0.776, Validation Accuracy:  0.769, Loss:  2.762
# Epoch   1 Batch   51/275 - Train Accuracy:  0.742, Validation Accuracy:  0.767, Loss:  2.828
# Epoch   1 Batch   52/275 - Train Accuracy:  0.770, Validation Accuracy:  0.763, Loss:  2.802
# Epoch   1 Batch   53/275 - Train Accuracy:  0.753, Validation Accuracy:  0.775, Loss:  2.790
# Epoch   1 Batch   54/275 - Train Accuracy:  0.742, Validation Accuracy:  0.771, Loss:  2.860
# Epoch   1 Batch   55/275 - Train Accuracy:  0.779, Validation Accuracy:  0.769, Loss:  2.794
# Epoch   1 Batch   56/275 - Train Accuracy:  0.777, Validation Accuracy:  0.769, Loss:  2.837
# Epoch   1 Batch   57/275 - Train Accuracy:  0.757, Validation Accuracy:  0.772, Loss:  2.831
# Epoch   1 Batch   58/275 - Train Accuracy:  0.754, Validation Accuracy:  0.779, Loss:  2.837
# Epoch   1 Batch   59/275 - Train Accuracy:  0.772, Validation Accuracy:  0.769, Loss:  2.829
# Epoch   1 Batch   60/275 - Train Accuracy:  0.785, Validation Accuracy:  0.769, Loss:  2.761
# Epoch   1 Batch   61/275 - Train Accuracy:  0.771, Validation Accuracy:  0.769, Loss:  2.805
# Epoch   1 Batch   62/275 - Train Accuracy:  0.756, Validation Accuracy:  0.777, Loss:  2.757
# Epoch   1 Batch   63/275 - Train Accuracy:  0.787, Validation Accuracy:  0.772, Loss:  2.760
# Epoch   1 Batch   64/275 - Train Accuracy:  0.776, Validation Accuracy:  0.784, Loss:  2.805
# Epoch   1 Batch   65/275 - Train Accuracy:  0.765, Validation Accuracy:  0.781, Loss:  2.786
# Epoch   1 Batch   66/275 - Train Accuracy:  0.796, Validation Accuracy:  0.787, Loss:  2.759
# Epoch   1 Batch   67/275 - Train Accuracy:  0.764, Validation Accuracy:  0.787, Loss:  2.752
# Epoch   1 Batch   68/275 - Train Accuracy:  0.763, Validation Accuracy:  0.787, Loss:  2.788
# Epoch   1 Batch   69/275 - Train Accuracy:  0.764, Validation Accuracy:  0.791, Loss:  2.823
# Epoch   1 Batch   70/275 - Train Accuracy:  0.770, Validation Accuracy:  0.779, Loss:  2.750
# Epoch   1 Batch   71/275 - Train Accuracy:  0.751, Validation Accuracy:  0.770, Loss:  2.835
# Epoch   1 Batch   72/275 - Train Accuracy:  0.804, Validation Accuracy:  0.782, Loss:  2.811
# Epoch   1 Batch   73/275 - Train Accuracy:  0.777, Validation Accuracy:  0.769, Loss:  2.815
# Epoch   1 Batch   74/275 - Train Accuracy:  0.785, Validation Accuracy:  0.790, Loss:  2.766
# Epoch   1 Batch   75/275 - Train Accuracy:  0.787, Validation Accuracy:  0.786, Loss:  2.808
# Epoch   1 Batch   76/275 - Train Accuracy:  0.791, Validation Accuracy:  0.793, Loss:  2.815
# Epoch   1 Batch   77/275 - Train Accuracy:  0.789, Validation Accuracy:  0.793, Loss:  2.806
# Epoch   1 Batch   78/275 - Train Accuracy:  0.778, Validation Accuracy:  0.801, Loss:  2.745
# Epoch   1 Batch   79/275 - Train Accuracy:  0.804, Validation Accuracy:  0.795, Loss:  2.757
# Epoch   1 Batch   80/275 - Train Accuracy:  0.800, Validation Accuracy:  0.799, Loss:  2.742
# Epoch   1 Batch   81/275 - Train Accuracy:  0.768, Validation Accuracy:  0.800, Loss:  2.786
# Epoch   1 Batch   82/275 - Train Accuracy:  0.804, Validation Accuracy:  0.801, Loss:  2.744
# Epoch   1 Batch   83/275 - Train Accuracy:  0.792, Validation Accuracy:  0.800, Loss:  2.798
# Epoch   1 Batch   84/275 - Train Accuracy:  0.823, Validation Accuracy:  0.807, Loss:  2.749
# Epoch   1 Batch   85/275 - Train Accuracy:  0.790, Validation Accuracy:  0.802, Loss:  2.799
# Epoch   1 Batch   86/275 - Train Accuracy:  0.792, Validation Accuracy:  0.791, Loss:  2.769
# Epoch   1 Batch   87/275 - Train Accuracy:  0.807, Validation Accuracy:  0.812, Loss:  2.783
# Epoch   1 Batch   88/275 - Train Accuracy:  0.777, Validation Accuracy:  0.798, Loss:  2.741
# Epoch   1 Batch   89/275 - Train Accuracy:  0.775, Validation Accuracy:  0.797, Loss:  2.770
# Epoch   1 Batch   90/275 - Train Accuracy:  0.784, Validation Accuracy:  0.800, Loss:  2.737
# Epoch   1 Batch   91/275 - Train Accuracy:  0.814, Validation Accuracy:  0.810, Loss:  2.737
# Epoch   1 Batch   92/275 - Train Accuracy:  0.783, Validation Accuracy:  0.806, Loss:  2.797
# Epoch   1 Batch   93/275 - Train Accuracy:  0.798, Validation Accuracy:  0.816, Loss:  2.773
# Epoch   1 Batch   94/275 - Train Accuracy:  0.825, Validation Accuracy:  0.816, Loss:  2.764
# Epoch   1 Batch   95/275 - Train Accuracy:  0.807, Validation Accuracy:  0.809, Loss:  2.765
# Epoch   1 Batch   96/275 - Train Accuracy:  0.788, Validation Accuracy:  0.803, Loss:  2.748
# Epoch   1 Batch   97/275 - Train Accuracy:  0.818, Validation Accuracy:  0.817, Loss:  2.781
# Epoch   1 Batch   98/275 - Train Accuracy:  0.813, Validation Accuracy:  0.822, Loss:  2.777
# Epoch   1 Batch   99/275 - Train Accuracy:  0.784, Validation Accuracy:  0.813, Loss:  2.737
# Epoch   1 Batch  100/275 - Train Accuracy:  0.812, Validation Accuracy:  0.818, Loss:  2.745
# Epoch   1 Batch  101/275 - Train Accuracy:  0.786, Validation Accuracy:  0.812, Loss:  2.781
# Epoch   1 Batch  102/275 - Train Accuracy:  0.827, Validation Accuracy:  0.810, Loss:  2.735
# Epoch   1 Batch  103/275 - Train Accuracy:  0.807, Validation Accuracy:  0.819, Loss:  2.760
# Epoch   1 Batch  104/275 - Train Accuracy:  0.816, Validation Accuracy:  0.818, Loss:  2.708
# Epoch   1 Batch  105/275 - Train Accuracy:  0.808, Validation Accuracy:  0.820, Loss:  2.729
# Epoch   1 Batch  106/275 - Train Accuracy:  0.806, Validation Accuracy:  0.817, Loss:  2.728
# Epoch   1 Batch  107/275 - Train Accuracy:  0.821, Validation Accuracy:  0.818, Loss:  2.772
# Epoch   1 Batch  108/275 - Train Accuracy:  0.814, Validation Accuracy:  0.808, Loss:  2.710
# Epoch   1 Batch  109/275 - Train Accuracy:  0.822, Validation Accuracy:  0.815, Loss:  2.733
# Epoch   1 Batch  110/275 - Train Accuracy:  0.835, Validation Accuracy:  0.821, Loss:  2.718
# Epoch   1 Batch  111/275 - Train Accuracy:  0.816, Validation Accuracy:  0.824, Loss:  2.753
# Epoch   1 Batch  112/275 - Train Accuracy:  0.797, Validation Accuracy:  0.824, Loss:  2.731
# Epoch   1 Batch  113/275 - Train Accuracy:  0.818, Validation Accuracy:  0.822, Loss:  2.712
# Epoch   1 Batch  114/275 - Train Accuracy:  0.817, Validation Accuracy:  0.816, Loss:  2.693
# Epoch   1 Batch  115/275 - Train Accuracy:  0.837, Validation Accuracy:  0.833, Loss:  2.731
# Epoch   1 Batch  116/275 - Train Accuracy:  0.824, Validation Accuracy:  0.822, Loss:  2.773
# Epoch   1 Batch  117/275 - Train Accuracy:  0.807, Validation Accuracy:  0.834, Loss:  2.759
# Epoch   1 Batch  118/275 - Train Accuracy:  0.833, Validation Accuracy:  0.824, Loss:  2.729
# Epoch   1 Batch  119/275 - Train Accuracy:  0.831, Validation Accuracy:  0.833, Loss:  2.732
# Epoch   1 Batch  120/275 - Train Accuracy:  0.839, Validation Accuracy:  0.834, Loss:  2.700
# Epoch   1 Batch  121/275 - Train Accuracy:  0.836, Validation Accuracy:  0.827, Loss:  2.720
# Epoch   1 Batch  122/275 - Train Accuracy:  0.816, Validation Accuracy:  0.819, Loss:  2.788
# Epoch   1 Batch  123/275 - Train Accuracy:  0.827, Validation Accuracy:  0.829, Loss:  2.739
# Epoch   1 Batch  124/275 - Train Accuracy:  0.830, Validation Accuracy:  0.825, Loss:  2.678
# Epoch   1 Batch  125/275 - Train Accuracy:  0.826, Validation Accuracy:  0.829, Loss:  2.717
# Epoch   1 Batch  126/275 - Train Accuracy:  0.826, Validation Accuracy:  0.823, Loss:  2.738
# Epoch   1 Batch  127/275 - Train Accuracy:  0.823, Validation Accuracy:  0.820, Loss:  2.767
# Epoch   1 Batch  128/275 - Train Accuracy:  0.844, Validation Accuracy:  0.821, Loss:  2.710
# Epoch   1 Batch  129/275 - Train Accuracy:  0.810, Validation Accuracy:  0.824, Loss:  2.753
# Epoch   1 Batch  130/275 - Train Accuracy:  0.825, Validation Accuracy:  0.817, Loss:  2.810
# Epoch   1 Batch  131/275 - Train Accuracy:  0.830, Validation Accuracy:  0.836, Loss:  2.703
# Epoch   1 Batch  132/275 - Train Accuracy:  0.835, Validation Accuracy:  0.829, Loss:  2.736
# Epoch   1 Batch  133/275 - Train Accuracy:  0.812, Validation Accuracy:  0.839, Loss:  2.721
# Epoch   1 Batch  134/275 - Train Accuracy:  0.819, Validation Accuracy:  0.850, Loss:  2.753
# Epoch   1 Batch  135/275 - Train Accuracy:  0.817, Validation Accuracy:  0.839, Loss:  2.754
# Epoch   1 Batch  136/275 - Train Accuracy:  0.831, Validation Accuracy:  0.836, Loss:  2.764
# Epoch   1 Batch  137/275 - Train Accuracy:  0.845, Validation Accuracy:  0.835, Loss:  2.688
# Epoch   1 Batch  138/275 - Train Accuracy:  0.828, Validation Accuracy:  0.833, Loss:  2.742
# Epoch   1 Batch  139/275 - Train Accuracy:  0.818, Validation Accuracy:  0.841, Loss:  2.761
# Epoch   1 Batch  140/275 - Train Accuracy:  0.823, Validation Accuracy:  0.837, Loss:  2.742
# Epoch   1 Batch  141/275 - Train Accuracy:  0.838, Validation Accuracy:  0.843, Loss:  2.688
# Epoch   1 Batch  142/275 - Train Accuracy:  0.848, Validation Accuracy:  0.835, Loss:  2.683
# Epoch   1 Batch  143/275 - Train Accuracy:  0.840, Validation Accuracy:  0.827, Loss:  2.742
# Epoch   1 Batch  144/275 - Train Accuracy:  0.837, Validation Accuracy:  0.844, Loss:  2.755
# Epoch   1 Batch  145/275 - Train Accuracy:  0.834, Validation Accuracy:  0.846, Loss:  2.739
# Epoch   1 Batch  146/275 - Train Accuracy:  0.847, Validation Accuracy:  0.853, Loss:  2.708
# Epoch   1 Batch  147/275 - Train Accuracy:  0.846, Validation Accuracy:  0.853, Loss:  2.705
# Epoch   1 Batch  148/275 - Train Accuracy:  0.844, Validation Accuracy:  0.843, Loss:  2.709
# Epoch   1 Batch  149/275 - Train Accuracy:  0.849, Validation Accuracy:  0.855, Loss:  2.692
# Epoch   1 Batch  150/275 - Train Accuracy:  0.832, Validation Accuracy:  0.843, Loss:  2.717
# Epoch   1 Batch  151/275 - Train Accuracy:  0.843, Validation Accuracy:  0.840, Loss:  2.701
# Epoch   1 Batch  152/275 - Train Accuracy:  0.830, Validation Accuracy:  0.851, Loss:  2.715
# Epoch   1 Batch  153/275 - Train Accuracy:  0.836, Validation Accuracy:  0.834, Loss:  2.704
# Epoch   1 Batch  154/275 - Train Accuracy:  0.855, Validation Accuracy:  0.834, Loss:  2.714
# Epoch   1 Batch  155/275 - Train Accuracy:  0.826, Validation Accuracy:  0.840, Loss:  2.783
# Epoch   1 Batch  156/275 - Train Accuracy:  0.822, Validation Accuracy:  0.823, Loss:  2.713
# Epoch   1 Batch  157/275 - Train Accuracy:  0.837, Validation Accuracy:  0.827, Loss:  2.669
# Epoch   1 Batch  158/275 - Train Accuracy:  0.828, Validation Accuracy:  0.835, Loss:  2.722
# Epoch   1 Batch  159/275 - Train Accuracy:  0.859, Validation Accuracy:  0.853, Loss:  2.700
# Epoch   1 Batch  160/275 - Train Accuracy:  0.853, Validation Accuracy:  0.854, Loss:  2.701
# Epoch   1 Batch  161/275 - Train Accuracy:  0.851, Validation Accuracy:  0.847, Loss:  2.687
# Epoch   1 Batch  162/275 - Train Accuracy:  0.840, Validation Accuracy:  0.843, Loss:  2.667
# Epoch   1 Batch  163/275 - Train Accuracy:  0.837, Validation Accuracy:  0.847, Loss:  2.747
# Epoch   1 Batch  164/275 - Train Accuracy:  0.835, Validation Accuracy:  0.849, Loss:  2.715
# Epoch   1 Batch  165/275 - Train Accuracy:  0.848, Validation Accuracy:  0.862, Loss:  2.708
# Epoch   1 Batch  166/275 - Train Accuracy:  0.854, Validation Accuracy:  0.861, Loss:  2.712
# Epoch   1 Batch  167/275 - Train Accuracy:  0.872, Validation Accuracy:  0.847, Loss:  2.738
# Epoch   1 Batch  168/275 - Train Accuracy:  0.855, Validation Accuracy:  0.856, Loss:  2.680
# Epoch   1 Batch  169/275 - Train Accuracy:  0.851, Validation Accuracy:  0.859, Loss:  2.669
# Epoch   1 Batch  170/275 - Train Accuracy:  0.860, Validation Accuracy:  0.859, Loss:  2.696
# Epoch   1 Batch  171/275 - Train Accuracy:  0.858, Validation Accuracy:  0.857, Loss:  2.719
# Epoch   1 Batch  172/275 - Train Accuracy:  0.860, Validation Accuracy:  0.859, Loss:  2.676
# Epoch   1 Batch  173/275 - Train Accuracy:  0.846, Validation Accuracy:  0.853, Loss:  2.709
# Epoch   1 Batch  174/275 - Train Accuracy:  0.844, Validation Accuracy:  0.854, Loss:  2.709
# Epoch   1 Batch  175/275 - Train Accuracy:  0.869, Validation Accuracy:  0.863, Loss:  2.702
# Epoch   1 Batch  176/275 - Train Accuracy:  0.856, Validation Accuracy:  0.851, Loss:  2.724
# Epoch   1 Batch  177/275 - Train Accuracy:  0.854, Validation Accuracy:  0.855, Loss:  2.706
# Epoch   1 Batch  178/275 - Train Accuracy:  0.862, Validation Accuracy:  0.859, Loss:  2.690
# Epoch   1 Batch  179/275 - Train Accuracy:  0.850, Validation Accuracy:  0.864, Loss:  2.764
# Epoch   1 Batch  180/275 - Train Accuracy:  0.827, Validation Accuracy:  0.856, Loss:  2.714
# Epoch   1 Batch  181/275 - Train Accuracy:  0.859, Validation Accuracy:  0.857, Loss:  2.675
# Epoch   1 Batch  182/275 - Train Accuracy:  0.855, Validation Accuracy:  0.861, Loss:  2.707
# Epoch   1 Batch  183/275 - Train Accuracy:  0.853, Validation Accuracy:  0.871, Loss:  2.659
# Epoch   1 Batch  184/275 - Train Accuracy:  0.872, Validation Accuracy:  0.859, Loss:  2.698
# Epoch   1 Batch  185/275 - Train Accuracy:  0.856, Validation Accuracy:  0.862, Loss:  2.671
# Epoch   1 Batch  186/275 - Train Accuracy:  0.848, Validation Accuracy:  0.860, Loss:  2.717
# Epoch   1 Batch  187/275 - Train Accuracy:  0.866, Validation Accuracy:  0.870, Loss:  2.676
# Epoch   1 Batch  188/275 - Train Accuracy:  0.872, Validation Accuracy:  0.865, Loss:  2.708
# Epoch   1 Batch  189/275 - Train Accuracy:  0.869, Validation Accuracy:  0.867, Loss:  2.685
# Epoch   1 Batch  190/275 - Train Accuracy:  0.866, Validation Accuracy:  0.863, Loss:  2.694
# Epoch   1 Batch  191/275 - Train Accuracy:  0.863, Validation Accuracy:  0.871, Loss:  2.699
# Epoch   1 Batch  192/275 - Train Accuracy:  0.855, Validation Accuracy:  0.875, Loss:  2.724
# Epoch   1 Batch  193/275 - Train Accuracy:  0.872, Validation Accuracy:  0.873, Loss:  2.729
# Epoch   1 Batch  194/275 - Train Accuracy:  0.866, Validation Accuracy:  0.875, Loss:  2.638
# Epoch   1 Batch  195/275 - Train Accuracy:  0.845, Validation Accuracy:  0.869, Loss:  2.716
# Epoch   1 Batch  196/275 - Train Accuracy:  0.852, Validation Accuracy:  0.868, Loss:  2.693
# Epoch   1 Batch  197/275 - Train Accuracy:  0.857, Validation Accuracy:  0.866, Loss:  2.721
# Epoch   1 Batch  198/275 - Train Accuracy:  0.864, Validation Accuracy:  0.867, Loss:  2.672
# Epoch   1 Batch  199/275 - Train Accuracy:  0.852, Validation Accuracy:  0.862, Loss:  2.667
# Epoch   1 Batch  200/275 - Train Accuracy:  0.858, Validation Accuracy:  0.866, Loss:  2.629
# Epoch   1 Batch  201/275 - Train Accuracy:  0.843, Validation Accuracy:  0.863, Loss:  2.635
# Epoch   1 Batch  202/275 - Train Accuracy:  0.846, Validation Accuracy:  0.866, Loss:  2.653
# Epoch   1 Batch  203/275 - Train Accuracy:  0.842, Validation Accuracy:  0.867, Loss:  2.721
# Epoch   1 Batch  204/275 - Train Accuracy:  0.858, Validation Accuracy:  0.870, Loss:  2.682
# Epoch   1 Batch  205/275 - Train Accuracy:  0.873, Validation Accuracy:  0.862, Loss:  2.658
# Epoch   1 Batch  206/275 - Train Accuracy:  0.855, Validation Accuracy:  0.864, Loss:  2.687
# Epoch   1 Batch  207/275 - Train Accuracy:  0.862, Validation Accuracy:  0.869, Loss:  2.680
# Epoch   1 Batch  208/275 - Train Accuracy:  0.867, Validation Accuracy:  0.874, Loss:  2.707
# Epoch   1 Batch  209/275 - Train Accuracy:  0.859, Validation Accuracy:  0.872, Loss:  2.698
# Epoch   1 Batch  210/275 - Train Accuracy:  0.864, Validation Accuracy:  0.869, Loss:  2.676
# Epoch   1 Batch  211/275 - Train Accuracy:  0.854, Validation Accuracy:  0.870, Loss:  2.638
# Epoch   1 Batch  212/275 - Train Accuracy:  0.863, Validation Accuracy:  0.876, Loss:  2.680
# Epoch   1 Batch  213/275 - Train Accuracy:  0.869, Validation Accuracy:  0.875, Loss:  2.683
# Epoch   1 Batch  214/275 - Train Accuracy:  0.872, Validation Accuracy:  0.880, Loss:  2.710
# Epoch   1 Batch  215/275 - Train Accuracy:  0.872, Validation Accuracy:  0.880, Loss:  2.688
# Epoch   1 Batch  216/275 - Train Accuracy:  0.873, Validation Accuracy:  0.881, Loss:  2.632
# Epoch   1 Batch  217/275 - Train Accuracy:  0.866, Validation Accuracy:  0.882, Loss:  2.641
# Epoch   1 Batch  218/275 - Train Accuracy:  0.853, Validation Accuracy:  0.884, Loss:  2.682
# Epoch   1 Batch  219/275 - Train Accuracy:  0.870, Validation Accuracy:  0.883, Loss:  2.672
# Epoch   1 Batch  220/275 - Train Accuracy:  0.870, Validation Accuracy:  0.874, Loss:  2.687
# Epoch   1 Batch  221/275 - Train Accuracy:  0.853, Validation Accuracy:  0.866, Loss:  2.669
# Epoch   1 Batch  222/275 - Train Accuracy:  0.855, Validation Accuracy:  0.870, Loss:  2.671
# Epoch   1 Batch  223/275 - Train Accuracy:  0.862, Validation Accuracy:  0.875, Loss:  2.734
# Epoch   1 Batch  224/275 - Train Accuracy:  0.874, Validation Accuracy:  0.880, Loss:  2.647
# Epoch   1 Batch  225/275 - Train Accuracy:  0.863, Validation Accuracy:  0.876, Loss:  2.679
# Epoch   1 Batch  226/275 - Train Accuracy:  0.870, Validation Accuracy:  0.872, Loss:  2.690
# Epoch   1 Batch  227/275 - Train Accuracy:  0.888, Validation Accuracy:  0.867, Loss:  2.643
# Epoch   1 Batch  228/275 - Train Accuracy:  0.875, Validation Accuracy:  0.870, Loss:  2.630
# Epoch   1 Batch  229/275 - Train Accuracy:  0.869, Validation Accuracy:  0.877, Loss:  2.682
# Epoch   1 Batch  230/275 - Train Accuracy:  0.858, Validation Accuracy:  0.875, Loss:  2.698
# Epoch   1 Batch  231/275 - Train Accuracy:  0.869, Validation Accuracy:  0.868, Loss:  2.688
# Epoch   1 Batch  232/275 - Train Accuracy:  0.865, Validation Accuracy:  0.863, Loss:  2.648
# Epoch   1 Batch  233/275 - Train Accuracy:  0.875, Validation Accuracy:  0.869, Loss:  2.680
# Epoch   1 Batch  234/275 - Train Accuracy:  0.861, Validation Accuracy:  0.879, Loss:  2.687
# Epoch   1 Batch  235/275 - Train Accuracy:  0.856, Validation Accuracy:  0.877, Loss:  2.654
# Epoch   1 Batch  236/275 - Train Accuracy:  0.870, Validation Accuracy:  0.880, Loss:  2.715
# Epoch   1 Batch  237/275 - Train Accuracy:  0.872, Validation Accuracy:  0.883, Loss:  2.676
# Epoch   1 Batch  238/275 - Train Accuracy:  0.857, Validation Accuracy:  0.882, Loss:  2.664
# Epoch   1 Batch  239/275 - Train Accuracy:  0.894, Validation Accuracy:  0.877, Loss:  2.665
# Epoch   1 Batch  240/275 - Train Accuracy:  0.870, Validation Accuracy:  0.872, Loss:  2.687
# Epoch   1 Batch  241/275 - Train Accuracy:  0.876, Validation Accuracy:  0.876, Loss:  2.667
# ...
# Epoch   4 Batch  103/275 - Train Accuracy:  0.916, Validation Accuracy:  0.911, Loss:  2.667
# Epoch   4 Batch  104/275 - Train Accuracy:  0.911, Validation Accuracy:  0.913, Loss:  2.634
# Epoch   4 Batch  105/275 - Train Accuracy:  0.915, Validation Accuracy:  0.917, Loss:  2.656
# Epoch   4 Batch  106/275 - Train Accuracy:  0.922, Validation Accuracy:  0.921, Loss:  2.599
# Epoch   4 Batch  107/275 - Train Accuracy:  0.920, Validation Accuracy:  0.921, Loss:  2.615
# Epoch   4 Batch  108/275 - Train Accuracy:  0.904, Validation Accuracy:  0.916, Loss:  2.677
# Epoch   4 Batch  109/275 - Train Accuracy:  0.926, Validation Accuracy:  0.923, Loss:  2.588
# Epoch   4 Batch  110/275 - Train Accuracy:  0.933, Validation Accuracy:  0.923, Loss:  2.608
# Epoch   4 Batch  111/275 - Train Accuracy:  0.921, Validation Accuracy:  0.919, Loss:  2.593
# Epoch   4 Batch  112/275 - Train Accuracy:  0.904, Validation Accuracy:  0.919, Loss:  2.618
# Epoch   4 Batch  113/275 - Train Accuracy:  0.905, Validation Accuracy:  0.923, Loss:  2.612
# Epoch   4 Batch  114/275 - Train Accuracy:  0.922, Validation Accuracy:  0.917, Loss:  2.668
# Epoch   4 Batch  115/275 - Train Accuracy:  0.914, Validation Accuracy:  0.912, Loss:  2.683
# Epoch   4 Batch  116/275 - Train Accuracy:  0.913, Validation Accuracy:  0.922, Loss:  2.657
# Epoch   4 Batch  117/275 - Train Accuracy:  0.903, Validation Accuracy:  0.909, Loss:  2.577
# Epoch   4 Batch  118/275 - Train Accuracy:  0.918, Validation Accuracy:  0.911, Loss:  2.631
# Epoch   4 Batch  119/275 - Train Accuracy:  0.920, Validation Accuracy:  0.912, Loss:  2.637
# Epoch   4 Batch  120/275 - Train Accuracy:  0.920, Validation Accuracy:  0.916, Loss:  2.615
# Epoch   4 Batch  121/275 - Train Accuracy:  0.918, Validation Accuracy:  0.917, Loss:  2.620
# Epoch   4 Batch  122/275 - Train Accuracy:  0.913, Validation Accuracy:  0.910, Loss:  2.648
# Epoch   4 Batch  123/275 - Train Accuracy:  0.912, Validation Accuracy:  0.919, Loss:  2.625
# Epoch   4 Batch  124/275 - Train Accuracy:  0.921, Validation Accuracy:  0.919, Loss:  2.612
# Epoch   4 Batch  125/275 - Train Accuracy:  0.915, Validation Accuracy:  0.917, Loss:  2.603
# Epoch   4 Batch  126/275 - Train Accuracy:  0.909, Validation Accuracy:  0.920, Loss:  2.644
# Epoch   4 Batch  127/275 - Train Accuracy:  0.926, Validation Accuracy:  0.923, Loss:  2.610
# Epoch   4 Batch  128/275 - Train Accuracy:  0.916, Validation Accuracy:  0.925, Loss:  2.569
# Epoch   4 Batch  129/275 - Train Accuracy:  0.908, Validation Accuracy:  0.916, Loss:  2.621
# Epoch   4 Batch  130/275 - Train Accuracy:  0.921, Validation Accuracy:  0.908, Loss:  2.607
# Epoch   4 Batch  131/275 - Train Accuracy:  0.919, Validation Accuracy:  0.908, Loss:  2.649
# Epoch   4 Batch  132/275 - Train Accuracy:  0.919, Validation Accuracy:  0.915, Loss:  2.620
# Epoch   4 Batch  133/275 - Train Accuracy:  0.911, Validation Accuracy:  0.913, Loss:  2.660
# Epoch   4 Batch  134/275 - Train Accuracy:  0.905, Validation Accuracy:  0.915, Loss:  2.622
# Epoch   4 Batch  135/275 - Train Accuracy:  0.902, Validation Accuracy:  0.918, Loss:  2.597
# Epoch   4 Batch  136/275 - Train Accuracy:  0.917, Validation Accuracy:  0.923, Loss:  2.605
# Epoch   4 Batch  137/275 - Train Accuracy:  0.913, Validation Accuracy:  0.918, Loss:  2.596
# Epoch   4 Batch  138/275 - Train Accuracy:  0.911, Validation Accuracy:  0.919, Loss:  2.609
# Epoch   4 Batch  139/275 - Train Accuracy:  0.901, Validation Accuracy:  0.913, Loss:  2.583
# Epoch   4 Batch  140/275 - Train Accuracy:  0.901, Validation Accuracy:  0.918, Loss:  2.646
# Epoch   4 Batch  141/275 - Train Accuracy:  0.916, Validation Accuracy:  0.912, Loss:  2.602
# Epoch   4 Batch  142/275 - Train Accuracy:  0.908, Validation Accuracy:  0.908, Loss:  2.611
# Epoch   4 Batch  143/275 - Train Accuracy:  0.924, Validation Accuracy:  0.914, Loss:  2.632
# Epoch   4 Batch  144/275 - Train Accuracy:  0.925, Validation Accuracy:  0.923, Loss:  2.593
# Epoch   4 Batch  145/275 - Train Accuracy:  0.912, Validation Accuracy:  0.922, Loss:  2.554
# Epoch   4 Batch  146/275 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  2.605
# Epoch   4 Batch  147/275 - Train Accuracy:  0.914, Validation Accuracy:  0.917, Loss:  2.599
# Epoch   4 Batch  148/275 - Train Accuracy:  0.934, Validation Accuracy:  0.914, Loss:  2.644
# Epoch   4 Batch  149/275 - Train Accuracy:  0.918, Validation Accuracy:  0.915, Loss:  2.626
# Epoch   4 Batch  150/275 - Train Accuracy:  0.915, Validation Accuracy:  0.911, Loss:  2.606
# Epoch   4 Batch  151/275 - Train Accuracy:  0.925, Validation Accuracy:  0.914, Loss:  2.580
# Epoch   4 Batch  152/275 - Train Accuracy:  0.912, Validation Accuracy:  0.915, Loss:  2.623
# Epoch   4 Batch  153/275 - Train Accuracy:  0.903, Validation Accuracy:  0.919, Loss:  2.626
# Epoch   4 Batch  154/275 - Train Accuracy:  0.924, Validation Accuracy:  0.920, Loss:  2.634
# Epoch   4 Batch  155/275 - Train Accuracy:  0.908, Validation Accuracy:  0.924, Loss:  2.636
# Epoch   4 Batch  156/275 - Train Accuracy:  0.921, Validation Accuracy:  0.918, Loss:  2.618
# Epoch   4 Batch  157/275 - Train Accuracy:  0.924, Validation Accuracy:  0.922, Loss:  2.686
# Epoch   4 Batch  158/275 - Train Accuracy:  0.910, Validation Accuracy:  0.919, Loss:  2.644
# Epoch   4 Batch  159/275 - Train Accuracy:  0.925, Validation Accuracy:  0.920, Loss:  2.619
# Epoch   4 Batch  160/275 - Train Accuracy:  0.925, Validation Accuracy:  0.926, Loss:  2.628
# Epoch   4 Batch  161/275 - Train Accuracy:  0.917, Validation Accuracy:  0.921, Loss:  2.612
# Epoch   4 Batch  162/275 - Train Accuracy:  0.910, Validation Accuracy:  0.914, Loss:  2.594
# Epoch   4 Batch  163/275 - Train Accuracy:  0.905, Validation Accuracy:  0.916, Loss:  2.616
# Epoch   4 Batch  164/275 - Train Accuracy:  0.924, Validation Accuracy:  0.921, Loss:  2.624
# Epoch   4 Batch  165/275 - Train Accuracy:  0.929, Validation Accuracy:  0.921, Loss:  2.646
# Epoch   4 Batch  166/275 - Train Accuracy:  0.919, Validation Accuracy:  0.922, Loss:  2.664
# Epoch   4 Batch  167/275 - Train Accuracy:  0.930, Validation Accuracy:  0.917, Loss:  2.620
# Epoch   4 Batch  168/275 - Train Accuracy:  0.926, Validation Accuracy:  0.920, Loss:  2.623
# Epoch   4 Batch  169/275 - Train Accuracy:  0.906, Validation Accuracy:  0.913, Loss:  2.583
# Epoch   4 Batch  170/275 - Train Accuracy:  0.925, Validation Accuracy:  0.915, Loss:  2.649
# Epoch   4 Batch  171/275 - Train Accuracy:  0.911, Validation Accuracy:  0.917, Loss:  2.656
# Epoch   4 Batch  172/275 - Train Accuracy:  0.909, Validation Accuracy:  0.916, Loss:  2.644
# Epoch   4 Batch  173/275 - Train Accuracy:  0.903, Validation Accuracy:  0.916, Loss:  2.534
# Epoch   4 Batch  174/275 - Train Accuracy:  0.916, Validation Accuracy:  0.915, Loss:  2.634
# Epoch   4 Batch  175/275 - Train Accuracy:  0.933, Validation Accuracy:  0.916, Loss:  2.608
# Epoch   4 Batch  176/275 - Train Accuracy:  0.911, Validation Accuracy:  0.916, Loss:  2.643
# Epoch   4 Batch  177/275 - Train Accuracy:  0.920, Validation Accuracy:  0.923, Loss:  2.548
# Epoch   4 Batch  178/275 - Train Accuracy:  0.927, Validation Accuracy:  0.922, Loss:  2.649
# Epoch   4 Batch  179/275 - Train Accuracy:  0.904, Validation Accuracy:  0.921, Loss:  2.625
# Epoch   4 Batch  180/275 - Train Accuracy:  0.911, Validation Accuracy:  0.923, Loss:  2.630
# Epoch   4 Batch  181/275 - Train Accuracy:  0.927, Validation Accuracy:  0.919, Loss:  2.622
# Epoch   4 Batch  182/275 - Train Accuracy:  0.924, Validation Accuracy:  0.916, Loss:  2.625
# Epoch   4 Batch  183/275 - Train Accuracy:  0.917, Validation Accuracy:  0.912, Loss:  2.640
# Epoch   4 Batch  184/275 - Train Accuracy:  0.913, Validation Accuracy:  0.915, Loss:  2.648
# Epoch   4 Batch  185/275 - Train Accuracy:  0.921, Validation Accuracy:  0.914, Loss:  2.624
# Epoch   4 Batch  186/275 - Train Accuracy:  0.907, Validation Accuracy:  0.917, Loss:  2.656
# Epoch   4 Batch  187/275 - Train Accuracy:  0.918, Validation Accuracy:  0.911, Loss:  2.617
# Epoch   4 Batch  188/275 - Train Accuracy:  0.923, Validation Accuracy:  0.912, Loss:  2.647
# Epoch   4 Batch  189/275 - Train Accuracy:  0.927, Validation Accuracy:  0.917, Loss:  2.659
# Epoch   4 Batch  190/275 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  2.627
# Epoch   4 Batch  191/275 - Train Accuracy:  0.929, Validation Accuracy:  0.923, Loss:  2.639
# Epoch   4 Batch  192/275 - Train Accuracy:  0.923, Validation Accuracy:  0.923, Loss:  2.643
# Epoch   4 Batch  193/275 - Train Accuracy:  0.925, Validation Accuracy:  0.927, Loss:  2.638
# Epoch   4 Batch  194/275 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  2.635
# Epoch   4 Batch  195/275 - Train Accuracy:  0.909, Validation Accuracy:  0.926, Loss:  2.667
# Epoch   4 Batch  196/275 - Train Accuracy:  0.910, Validation Accuracy:  0.923, Loss:  2.599
# Epoch   4 Batch  197/275 - Train Accuracy:  0.914, Validation Accuracy:  0.919, Loss:  2.608
# Epoch   4 Batch  198/275 - Train Accuracy:  0.908, Validation Accuracy:  0.922, Loss:  2.638
# Epoch   4 Batch  199/275 - Train Accuracy:  0.900, Validation Accuracy:  0.918, Loss:  2.598
# Epoch   4 Batch  200/275 - Train Accuracy:  0.915, Validation Accuracy:  0.916, Loss:  2.595
# Epoch   4 Batch  201/275 - Train Accuracy:  0.894, Validation Accuracy:  0.904, Loss:  2.618
# Epoch   4 Batch  202/275 - Train Accuracy:  0.917, Validation Accuracy:  0.910, Loss:  2.627
# Epoch   4 Batch  203/275 - Train Accuracy:  0.907, Validation Accuracy:  0.919, Loss:  2.597
# Epoch   4 Batch  204/275 - Train Accuracy:  0.918, Validation Accuracy:  0.923, Loss:  2.617
# Epoch   4 Batch  205/275 - Train Accuracy:  0.927, Validation Accuracy:  0.919, Loss:  2.618
# Epoch   4 Batch  206/275 - Train Accuracy:  0.920, Validation Accuracy:  0.918, Loss:  2.644
# Epoch   4 Batch  207/275 - Train Accuracy:  0.909, Validation Accuracy:  0.917, Loss:  2.622
# Epoch   4 Batch  208/275 - Train Accuracy:  0.916, Validation Accuracy:  0.920, Loss:  2.619
# Epoch   4 Batch  209/275 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  2.622
# Epoch   4 Batch  210/275 - Train Accuracy:  0.923, Validation Accuracy:  0.918, Loss:  2.616
# Epoch   4 Batch  211/275 - Train Accuracy:  0.905, Validation Accuracy:  0.914, Loss:  2.637
# Epoch   4 Batch  212/275 - Train Accuracy:  0.915, Validation Accuracy:  0.920, Loss:  2.649
# Epoch   4 Batch  213/275 - Train Accuracy:  0.918, Validation Accuracy:  0.915, Loss:  2.587
# Epoch   4 Batch  214/275 - Train Accuracy:  0.916, Validation Accuracy:  0.922, Loss:  2.660
# Epoch   4 Batch  215/275 - Train Accuracy:  0.915, Validation Accuracy:  0.921, Loss:  2.620
# Epoch   4 Batch  216/275 - Train Accuracy:  0.916, Validation Accuracy:  0.915, Loss:  2.677
# Epoch   4 Batch  217/275 - Train Accuracy:  0.914, Validation Accuracy:  0.913, Loss:  2.630
# Epoch   4 Batch  218/275 - Train Accuracy:  0.916, Validation Accuracy:  0.924, Loss:  2.658
# Epoch   4 Batch  219/275 - Train Accuracy:  0.918, Validation Accuracy:  0.924, Loss:  2.588
# Epoch   4 Batch  220/275 - Train Accuracy:  0.925, Validation Accuracy:  0.913, Loss:  2.617
# Epoch   4 Batch  221/275 - Train Accuracy:  0.914, Validation Accuracy:  0.919, Loss:  2.634
# Epoch   4 Batch  222/275 - Train Accuracy:  0.908, Validation Accuracy:  0.917, Loss:  2.603
# Epoch   4 Batch  223/275 - Train Accuracy:  0.913, Validation Accuracy:  0.914, Loss:  2.582
# Epoch   4 Batch  224/275 - Train Accuracy:  0.915, Validation Accuracy:  0.917, Loss:  2.644
# Epoch   4 Batch  225/275 - Train Accuracy:  0.916, Validation Accuracy:  0.925, Loss:  2.616
# Epoch   4 Batch  226/275 - Train Accuracy:  0.908, Validation Accuracy:  0.923, Loss:  2.613
# Epoch   4 Batch  227/275 - Train Accuracy:  0.918, Validation Accuracy:  0.922, Loss:  2.637
# Epoch   4 Batch  228/275 - Train Accuracy:  0.915, Validation Accuracy:  0.917, Loss:  2.649
# Epoch   4 Batch  229/275 - Train Accuracy:  0.916, Validation Accuracy:  0.918, Loss:  2.589
# Epoch   4 Batch  230/275 - Train Accuracy:  0.906, Validation Accuracy:  0.918, Loss:  2.641
# Epoch   4 Batch  231/275 - Train Accuracy:  0.908, Validation Accuracy:  0.922, Loss:  2.609
# Epoch   4 Batch  232/275 - Train Accuracy:  0.913, Validation Accuracy:  0.930, Loss:  2.637
# Epoch   4 Batch  233/275 - Train Accuracy:  0.915, Validation Accuracy:  0.922, Loss:  2.607
# Epoch   4 Batch  234/275 - Train Accuracy:  0.922, Validation Accuracy:  0.912, Loss:  2.611
# Epoch   4 Batch  235/275 - Train Accuracy:  0.920, Validation Accuracy:  0.915, Loss:  2.627
# Epoch   4 Batch  236/275 - Train Accuracy:  0.906, Validation Accuracy:  0.927, Loss:  2.605
# Epoch   4 Batch  237/275 - Train Accuracy:  0.917, Validation Accuracy:  0.917, Loss:  2.611
# Epoch   4 Batch  238/275 - Train Accuracy:  0.913, Validation Accuracy:  0.915, Loss:  2.635
# Epoch   4 Batch  239/275 - Train Accuracy:  0.935, Validation Accuracy:  0.922, Loss:  2.598
# Epoch   4 Batch  240/275 - Train Accuracy:  0.926, Validation Accuracy:  0.915, Loss:  2.612
# Epoch   4 Batch  241/275 - Train Accuracy:  0.937, Validation Accuracy:  0.921, Loss:  2.633
# Epoch   4 Batch  242/275 - Train Accuracy:  0.916, Validation Accuracy:  0.925, Loss:  2.633
# Epoch   4 Batch  243/275 - Train Accuracy:  0.919, Validation Accuracy:  0.924, Loss:  2.653
# Epoch   4 Batch  244/275 - Train Accuracy:  0.916, Validation Accuracy:  0.918, Loss:  2.648
# Epoch   4 Batch  245/275 - Train Accuracy:  0.919, Validation Accuracy:  0.923, Loss:  2.634
# Epoch   4 Batch  246/275 - Train Accuracy:  0.925, Validation Accuracy:  0.915, Loss:  2.595
# Epoch   4 Batch  247/275 - Train Accuracy:  0.900, Validation Accuracy:  0.915, Loss:  2.637
# Epoch   4 Batch  248/275 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  2.644
# Epoch   4 Batch  249/275 - Train Accuracy:  0.931, Validation Accuracy:  0.924, Loss:  2.634
# Epoch   4 Batch  250/275 - Train Accuracy:  0.912, Validation Accuracy:  0.927, Loss:  2.640
# Epoch   4 Batch  251/275 - Train Accuracy:  0.917, Validation Accuracy:  0.914, Loss:  2.635
# Epoch   4 Batch  252/275 - Train Accuracy:  0.918, Validation Accuracy:  0.920, Loss:  2.631
# Epoch   4 Batch  253/275 - Train Accuracy:  0.917, Validation Accuracy:  0.914, Loss:  2.640
# Epoch   4 Batch  254/275 - Train Accuracy:  0.921, Validation Accuracy:  0.923, Loss:  2.631
# Epoch   4 Batch  255/275 - Train Accuracy:  0.931, Validation Accuracy:  0.918, Loss:  2.672
# Epoch   4 Batch  256/275 - Train Accuracy:  0.921, Validation Accuracy:  0.921, Loss:  2.625
# Epoch   4 Batch  257/275 - Train Accuracy:  0.928, Validation Accuracy:  0.922, Loss:  2.612
# Epoch   4 Batch  258/275 - Train Accuracy:  0.926, Validation Accuracy:  0.919, Loss:  2.624
# Epoch   4 Batch  259/275 - Train Accuracy:  0.911, Validation Accuracy:  0.920, Loss:  2.624
# Epoch   4 Batch  260/275 - Train Accuracy:  0.917, Validation Accuracy:  0.912, Loss:  2.669
# Epoch   4 Batch  261/275 - Train Accuracy:  0.918, Validation Accuracy:  0.913, Loss:  2.609
# Epoch   4 Batch  262/275 - Train Accuracy:  0.914, Validation Accuracy:  0.917, Loss:  2.610
# Epoch   4 Batch  263/275 - Train Accuracy:  0.910, Validation Accuracy:  0.917, Loss:  2.625
# Epoch   4 Batch  264/275 - Train Accuracy:  0.914, Validation Accuracy:  0.914, Loss:  2.608
# Epoch   4 Batch  265/275 - Train Accuracy:  0.926, Validation Accuracy:  0.918, Loss:  2.643
# Epoch   4 Batch  266/275 - Train Accuracy:  0.921, Validation Accuracy:  0.916, Loss:  2.568
# Epoch   4 Batch  267/275 - Train Accuracy:  0.921, Validation Accuracy:  0.921, Loss:  2.657
# Epoch   4 Batch  268/275 - Train Accuracy:  0.924, Validation Accuracy:  0.916, Loss:  2.616
# Epoch   4 Batch  269/275 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  2.634
# Epoch   4 Batch  270/275 - Train Accuracy:  0.912, Validation Accuracy:  0.925, Loss:  2.643
# Epoch   4 Batch  271/275 - Train Accuracy:  0.908, Validation Accuracy:  0.921, Loss:  2.639
# Epoch   4 Batch  272/275 - Train Accuracy:  0.916, Validation Accuracy:  0.923, Loss:  2.608
# Epoch   4 Batch  273/275 - Train Accuracy:  0.916, Validation Accuracy:  0.918, Loss:  2.593
# Model Trained and Saved

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return [vocab_to_int[i] if i in vocab_to_int else vocab_to_int['<UNK>'] for i in sentence.lower().split(' ')]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [77, 4, 217, 78, 37, 58, 211]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [6, 191, 294, 273, 22, 75, 196, 355, 1]
#   French Words: ['il', 'a', 'vu', 'un', 'vieux', 'camion', 'jaune', '.', '<EOS>']

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
